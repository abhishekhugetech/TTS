# %%
# %ls
# Out:
# CITATION.cff                      notebooks/
# CODE_OF_CONDUCT.md                output copy.mp3
# CODE_OWNERS.rst                   output.mp3
# CONTRIBUTING.md                   output.wav
# Dockerfile                        pyproject.toml
# LICENSE.txt                       recipes/
# MANIFEST.in                       requirements.dev.txt
# Makefile                          requirements.ja.txt
# OpenCV Face detection.ipynb       requirements.notebooks.txt
# README.md                         requirements.txt
# TTS/                              run_bash_tests.sh*
# TestTTS.ipynb                     scripts/
# dockerfiles/                      setup.cfg
# docs/                             setup.py
# files/                            start.sh
# hubconf.py                        tests/
# images/                           yolov8-face-landmarks-opencv-dnn/

# %%
# !python3 TTS/server/server.py --list_models #To get the list of available models
# Out:
#  Name format: type/language/dataset/model
#  1: tts_models/multilingual/multi-dataset/xtts_v2 [already downloaded]
#  2: tts_models/multilingual/multi-dataset/xtts_v1.1
#  3: tts_models/multilingual/multi-dataset/your_tts [already downloaded]
#  4: tts_models/multilingual/multi-dataset/bark [already downloaded]
#  5: tts_models/bg/cv/vits
#  6: tts_models/cs/cv/vits
#  7: tts_models/da/cv/vits
#  8: tts_models/et/cv/vits
#  9: tts_models/ga/cv/vits
#  10: tts_models/en/ek1/tacotron2
#  11: tts_models/en/ljspeech/tacotron2-DDC
#  12: tts_models/en/ljspeech/tacotron2-DDC_ph
#  13: tts_models/en/ljspeech/glow-tts
#  14: tts_models/en/ljspeech/speedy-speech
#  15: tts_models/en/ljspeech/tacotron2-DCA
#  16: tts_models/en/ljspeech/vits
#  17: tts_models/en/ljspeech/vits--neon
#  18: tts_models/en/ljspeech/fast_pitch
#  19: tts_models/en/ljspeech/overflow
#  20: tts_models/en/ljspeech/neural_hmm
#  21: tts_models/en/vctk/vits [already downloaded]
#  22: tts_models/en/vctk/fast_pitch
# ...

# %%
# !pip install TTS

# %%
import torch
from TTS.api import TTS

# Get device
device = "cuda" if torch.cuda.is_available() else "cpu"

# List available 🐸TTS models
print(TTS().list_models())

# %%
# %ls
# Out:
# CITATION.cff                      notebooks/
# CODE_OF_CONDUCT.md                output copy.mp3
# CODE_OWNERS.rst                   output.mp3
# CONTRIBUTING.md                   output.wav
# Dockerfile                        pyproject.toml
# LICENSE.txt                       recipes/
# MANIFEST.in                       requirements.dev.txt
# Makefile                          requirements.ja.txt
# OpenCV Face detection.ipynb       requirements.notebooks.txt
# README.md                         requirements.txt
# TTS/                              run_bash_tests.sh*
# TestTTS.ipynb                     scripts/
# dockerfiles/                      setup.cfg
# docs/                             setup.py
# files/                            start.sh
# hubconf.py                        tests/
# images/                           yolov8-face-landmarks-opencv-dnn/

# %%
# !pip install -r requirements.txt
# Out:
# Ignoring numpy: markers 'python_version > "3.10"' don't match your environment
# Ignoring numba: markers 'python_version < "3.9"' don't match your environment
# ...

# %%
# !python3 TTS/server/server.py --list_models #To get the list of available models
# Out:
#  Name format: type/language/dataset/model
#  1: tts_models/multilingual/multi-dataset/xtts_v2 [already downloaded]
#  2: tts_models/multilingual/multi-dataset/xtts_v1.1
#  3: tts_models/multilingual/multi-dataset/your_tts [already downloaded]
#  4: tts_models/multilingual/multi-dataset/bark [already downloaded]
#  5: tts_models/bg/cv/vits
#  6: tts_models/cs/cv/vits
#  7: tts_models/da/cv/vits
#  8: tts_models/et/cv/vits
#  9: tts_models/ga/cv/vits
#  10: tts_models/en/ek1/tacotron2
#  11: tts_models/en/ljspeech/tacotron2-DDC
#  12: tts_models/en/ljspeech/tacotron2-DDC_ph
#  13: tts_models/en/ljspeech/glow-tts
#  14: tts_models/en/ljspeech/speedy-speech
#  15: tts_models/en/ljspeech/tacotron2-DCA
#  16: tts_models/en/ljspeech/vits
#  17: tts_models/en/ljspeech/vits--neon
#  18: tts_models/en/ljspeech/fast_pitch
#  19: tts_models/en/ljspeech/overflow
#  20: tts_models/en/ljspeech/neural_hmm
#  21: tts_models/en/vctk/vits [already downloaded]
#  22: tts_models/en/vctk/fast_pitch
# ...

# %%
# !python3 TTS/server/server.py --model_name tts_models/en/vctk/vits # To start a server

# %%
import torch
import os
from TTS.api import TTS

# PYTORCH_ENABLE_MPS_FALLBACK=1
# os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
# print(os.environ["PYTORCH_ENABLE_MPS_FALLBACK"])
# return


# Get device
device = "cuda" if torch.cuda.is_available() else "cpu"

# List available 🐸TTS models
print(TTS().list_models())


 # 1: tts_models/multilingual/multi-dataset/xtts_v2
 # 2: tts_models/multilingual/multi-dataset/xtts_v1.1
 # 3: tts_models/multilingual/multi-dataset/your_tts [already downloaded]
 # 4: tts_models/multilingual/multi-dataset/bark
# Init TTS
# tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", progress_bar=True).to(device)
tts = TTS("tts_models/eng/fairseq/vits", progress_bar=True).to(device)




# Run TTS
# ❗ Since this model is multi-lingual voice cloning model, we must set the target speaker_wav and language
# Text to speech list of amplitude values as output
# wav = tts.tts(text="Hello world!", speaker_wav="my/cloning/audio.wav", language="hi")
# Text to speech to a file
# tts.tts_to_file(text="Hello world!", speaker_wav="my/cloning/audio.wav", language="hi", file_path="output.wav")
text = "मैं समझ सकता हूँ कि अंग्रेजी में समझना शायद थोड़ा कठिन हो रहा होगा। चलो, इसे हिंदी में समझते हैं। सोचो कि परमाणु एक छोटा सा सौर मंडल है। बीच में जो सूरज है, वो परमाणु का नाभिक है, और जो ग्रह उसके आसपास घूम रहे हैं, वो इलेक्ट्रॉन हैं। बोर ने कहा कि ये इलेक्ट्रॉन कहीं भी नहीं घूम सकते - उनके घूमने के लिए कुछ ख़ास रास्ते या 'ऊर्जा स्तर' होते हैं। क्या इस तरह समझने में आसानी हुई ? बताओ, कौन सा हिस्सा अभी भी समझ नहीं आया, हम उसे साथ मिलकर समझेंगे।"
# tts.tts_to_file(text=text, speaker_wav="./files/kalam_l.mp3", language="hi", file_path="output_kalam.mp3")
tts.tts_to_file(text=text, speaker_wav="./files/kalam_l.mp3", file_path="output_kalam.mp3")
# Out:
# ...
# Hola
#  > tts_models/eng/fairseq/vits is already downloaded.
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Text splitted to sentences.
# ...

# %%
import torch
import os
from TTS.api import TTS

# PYTORCH_ENABLE_MPS_FALLBACK=1
# os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
# print(os.environ["PYTORCH_ENABLE_MPS_FALLBACK"])
# return


# Get device
# device = "cuda" if torch.cuda.is_available() else "cpu"

# List available 🐸TTS models
print(TTS().list_models())


 # 1: tts_models/multilingual/multi-dataset/xtts_v2
 # 2: tts_models/multilingual/multi-dataset/xtts_v1.1
 # 3: tts_models/multilingual/multi-dataset/your_tts [already downloaded]
 # 4: tts_models/multilingual/multi-dataset/bark
# Init TTS
# tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", progress_bar=True).to(device)
tts = TTS("tts_models/de/thorsten/tacotron2-DDC")


# Run TTS
# ❗ Since this model is multi-lingual voice cloning model, we must set the target speaker_wav and language
# Text to speech list of amplitude values as output
# wav = tts.tts(text="Hello world!", speaker_wav="my/cloning/audio.wav", language="hi")
# Text to speech to a file
# tts.tts_to_file(text="Hello world!", speaker_wav="my/cloning/audio.wav", language="hi", file_path="output.wav")
text = "I was always fascinated by nature's wonders. My teachers, especially my science teacher, nurtured this curiosity. This led me to pursue science.I dreamt of India becoming a developed nation, standing tall in the world. This means eradicating poverty, being a leader in technology and ensuring a good quality of life for all Indians.  We need to work together to achieve this. Failures are inevitable, my dear friend.  They are stepping stones to success.  Learn from your mistakes, don't be afraid to try again, and never give up on your dreams. My dear friend, the world is in need of solutions. As a skilled programmer with a strong marketing team, you can address many challenges. Think about healthcare, education, or even agriculture. Could you develop software that improves healthcare delivery, makes education more accessible, or helps farmers increase their yield? Identify a problem that resonates with you, and use your skills to build a solution. Remember, entrepreneurship is about solving problems and making a positive impact."
tts.tts_to_file(text=text, speaker_wav="./files/kalam_l.mp3", language="en", file_path="output_kalam.mp3")

tts.tts_with_vc_to_file(
    text,
    speaker_wav="target/speaker.wav",
    file_path="output.wav"
)
# Out:
# ...
#  > Downloading model to /Users/abhishekkumarsingh/Library/Application Support/tts/tts_models--de--thorsten--tacotron2-DDC
# 100%|████████████████████████████████████████████████████▉| 522M/523M [00:30<00:00, 19.6MiB/s]
#  > Model's license - apache 2.0
#  > Check https://choosealicense.com/licenses/apache-2.0/ for more info.
#  > Downloading model to /Users/abhishekkumarsingh/Library/Application Support/tts/vocoder_models--de--thorsten--hifigan_v1
# 100%|█████████████████████████████████████████████████████| 523M/523M [00:35<00:00, 14.6MiB/s]
#
#   0%|                                                     | 282k/939M [00:00<05:33, 2.82MiB/s]
#   0%|                                                     | 634k/939M [00:00<04:52, 3.20MiB/s]
#   0%|                                                    | 1.03M/939M [00:00<04:24, 3.55MiB/s]
#   0%|                                                    | 1.47M/939M [00:00<04:05, 3.82MiB/s]
# ...

# %%
# %ls
# %cd ..
# Out:
# CITATION.cff                      notebooks/
# CODE_OF_CONDUCT.md                output copy.mp3
# CODE_OWNERS.rst                   output.mp3
# CONTRIBUTING.md                   output.wav
# Dockerfile                        pyproject.toml
# LICENSE.txt                       recipes/
# MANIFEST.in                       requirements.dev.txt
# Makefile                          requirements.ja.txt
# OpenCV Face detection.ipynb       requirements.notebooks.txt
# README.md                         requirements.txt
# TTS/                              run_bash_tests.sh*
# TestTTS.ipynb                     scripts/
# dockerfiles/                      setup.cfg
# docs/                             setup.py
# files/                            start.sh
# hubconf.py                        tests/
# images/                           yolov8-face-landmarks-opencv-dnn/

# %%
import torch
from TTS.api import TTS

# Get device
device = "cuda" if torch.cuda.is_available() else "cpu"

# List available 🐸TTS models
# print(TTS().list_models())

# Init TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)

# Run TTS
# ❗ Since this model is multi-lingual voice cloning model, we must set the target speaker_wav and language
# Text to speech list of amplitude values as output
# wav = tts.tts(text="Hello world!", language="en")
# Text to speech to a file
tts.tts_to_file(text="Since this model is multi-lingual voice cloning model, we must set the target speaker_wav and language Text to speech list of amplitude values as output", language="en", file_path="output_en.mp3")
# Out:
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 18
#      11 tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)
#      13 # Run TTS
#      14 # ❗ Since this model is multi-lingual voice cloning model, we must set the target speaker_wav and language
#      15 # Text to speech list of amplitude values as output
#      16 # wav = tts.tts(text="Hello world!", language="en")
#      17 # Text to speech to a file
# ---> 18 tts.tts_to_file(text="Since this model is multi-lingual voice cloning model, we must set the target speaker_wav and language Text to speech list of amplitude values as output", language="en", file_path="output_en.mp3")
#
# ...
